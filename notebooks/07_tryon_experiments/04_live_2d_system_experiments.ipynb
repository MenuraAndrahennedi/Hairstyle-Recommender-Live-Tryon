# %% [markdown]
# # Live 2D System Runner

# %%
from pathlib import Path
import subprocess
import sys

PROJECT_ROOT = Path.cwd().resolve()
while not (PROJECT_ROOT / "backend").exists() and PROJECT_ROOT.parent != PROJECT_ROOT:
    PROJECT_ROOT = PROJECT_ROOT.parent

PYTHON_EXE = PROJECT_ROOT / ".venv" / "Scripts" / "python.exe"
if not PYTHON_EXE.exists():
    PYTHON_EXE = Path(sys.executable)

LIVE_SCRIPT = PROJECT_ROOT / "backend" / "systems" / "live_2d" / "scripts" / "run_webcam_demo.py"

PROJECT_ROOT, PYTHON_EXE, LIVE_SCRIPT
# Out:
# (WindowsPath('D:/Projects/Personal Projects/Hairstyle Recommender Live Tryon'),
#  WindowsPath('D:/Projects/Personal Projects/Hairstyle Recommender Live Tryon/.venv/Scripts/python.exe'),
#  WindowsPath('D:/Projects/Personal Projects/Hairstyle Recommender Live Tryon/backend/systems/live_2d/scripts/run_webcam_demo.py'))

# %%
if not LIVE_SCRIPT.exists():
    raise FileNotFoundError(LIVE_SCRIPT)

completed = subprocess.run(
    [str(PYTHON_EXE), str(LIVE_SCRIPT)],
    cwd=str(PROJECT_ROOT),
    capture_output=True,
    text=True,
)

if completed.stdout.strip():
    print(completed.stdout)
if completed.stderr.strip():
    print(completed.stderr)
if completed.returncode != 0:
    raise RuntimeError(f"live_2d runner exited with code {completed.returncode}")
# Out:
# Live 2D project engine loaded.
# System root: D:\Projects\Personal Projects\Hairstyle Recommender Live Tryon\backend\systems\live_2d
# Opened webcam with backend: default at camera index: 0
#
# Controls:
# Arrow keys = move hair
# W / S = increase/decrease size
# A / D = rotate left/right
# 1 / 2 / 3 = choose recommended asset
# R = cycle recommendation
# T = reset tuning
# Q = quit
#
# W0000 00:00:1778134268.148489   22752 face_landmarker_graph.cc:180] Sets FaceBlendshapesGraph acceleration to xnnpack by default.
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1778134268.231946   23260 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1778134268.252013   24992 inference_feedback_manager.cc:121] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
